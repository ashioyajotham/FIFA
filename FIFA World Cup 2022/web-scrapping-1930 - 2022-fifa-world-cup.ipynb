# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
years = [1930, 1934, 1938, 1942, 1946, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982, 1986, 
         1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018]

# %%
url = "https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup"

# %%
import requests
response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>\n<script type="text/javascript">window.addEventListener(\'DOMContentLoaded\',function(){var v=archive_analytics.values;v.service=\'wb\';v.server_name=\'wwwb-app227.us.archive.org\';v.server_ms=400;archive_analytics.send_pageview({});});</script>\n<script type="text/javascript" src="/_static/js/bundle-playback.js?v=MzYkZ0TU" charset="utf-8"></script>\n<script type="text/javascript" src="/_static/js/wombat.js?v=UHAOicsW" charset="utf-8"></script>\n<script type="text/javascript">\n  __wm.init("https://web.archive.org/web");\n  __wm.wombat("https://en.wikipedia.org/wiki/2022_FIFA_World_Cup","20221115040351","https://web.archive.org/","web","/_static/",\n\t      "1668485031");\n</script>\n<link rel="stylesheet" type="text/css" href="/_static/css/banner-styles.css?v=S1zqJCYt" />\n<link rel="stylesheet" type="text/css" href="/_static/css/iconochive.css?v=qtvMKcIJ" />\n<!-- End Wayback Rewrite JS Include -->\n\n<meta charset="UTF-8"/>\n<title>2022 FIFA World Cup - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"9ae91d00-0d95-4109-80e9-e234ffc2c1f0","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"2022_FIFA_World_Cup","wgTitle":"2022 FIFA World Cup","wgCurRevisionId":1121930998,"wgRevisionId":1121930998,"wgArticleId":17742072,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","CS1 French-language sources (fr)","Webarchive template wayback links","CS1 Swedish-language sources (sv)","CS1 Czech-language sources (cs)","CS1 Spanish-language sources (es)","Articles with short description","Short description matches Wikidata",\n"Wikipedia indefinitely semi-protected pages","Use British English from September 2022","Use dmy dates from November 2022","Short description is different from Wikidata","All articles with unsourced statements","Articles with unsourced statements from February 2022","Pages using sports table with possibly ignored parameters","Articles with unsourced statements from November 2022","Articles needing the year an event occurred from July 2015","Commons category link from Wikidata","Official website different in Wikidata and Wikipedia","AC with 0 elements","2022 FIFA World Cup","FIFA World Cup tournaments","2022 in association football","2022–23 in Qatari football","International association football competitions hosted by Qatar","Scheduled association football competitions","November 2022 sports events in Asia","December 2022 sports events in Asia","Association football controversies","Sports events affected by the 2022 Russian invasion of Ukraine"],"wgPageContentLanguage":"en",\n"wgPageContentModel":"wikitext","wgRelevantPageName":"2022_FIFA_World_Cup","wgRelevantArticleId":17742072,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["sysop"],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":200000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgU ...

# %%
content = response.text
soup = BeautifulSoup(content, "lxml")

# %%
soup.find_all("h2")
# Out:
# [<h2 id="mw-toc-heading">Contents</h2>,
#  <h2><span class="mw-headline" id="Host_selection">Host selection</span></h2>,
#  <h2><span class="mw-headline" id="Teams">Teams</span></h2>,
#  <h2><span class="mw-headline" id="Officiating">Officiating</span></h2>,
#  <h2><span class="mw-headline" id="Venues">Venues</span></h2>,
#  <h2><span class="mw-headline" id="Schedule">Schedule</span></h2>,
#  <h2><span class="mw-headline" id="Opening_ceremony">Opening ceremony</span></h2>,
#  <h2><span class="mw-headline" id="Group_stage">Group stage</span></h2>,
#  <h2><span class="mw-headline" id="Knockout_stage">Knockout stage</span></h2>,
#  <h2><span class="mw-headline" id="Prize_money">Prize money</span></h2>,
#  <h2><span class="mw-headline" id="Marketing">Marketing</span></h2>,
#  <h2><span class="mw-headline" id="Symbols">Symbols</span></h2>,
#  <h2><span class="mw-headline" id="Controversies">Controversies</span></h2>,
#  <h2><span class="mw-headline" id="See_also">See also</span></h2>,
#  <h2><span class="mw-headline" id="Notes">Notes</span></h2>,
#  <h2><span class="mw-headline" id="References">References</span></h2>,
#  <h2><span class="mw-headline" id="External_links">External links</span></h2>,
#  <h2>Navigation menu</h2>]

# %% [markdown]
# ### Testing with 2014

# %%
# List of all matches
matches = soup.find_all("div", class_="footballbox") # where div is the tag

home = []
score = []
away = []

for match in matches:
    home.append(match.find("th", class_="fhome").get_text())
    score.append(match.find("th", class_="fscore").get_text())
    away.append(match.find("th", class_="faway").get_text())
    
# Create a dictionary
fifa_dict = {"home":home, "score":home, "away":away}

#Create a df
fifa_df = pd.DataFrame(fifa_dict)
fifa_df["year"] = "2014"
fifa_df.head()
# Out:
#            home         score          away  year
# 0        Qatar         Qatar        Ecuador  2014
# 1      Senegal       Senegal    Netherlands  2014
# 2        Qatar         Qatar        Senegal  2014
# 3  Netherlands   Netherlands        Ecuador  2014
# 4      Ecuador       Ecuador        Senegal  2014

# %% [markdown]
# ### Every year since 1930

# %%
def get_matches(year):
    url = f"https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup"
    response = requests.get(url)
    content = response.text
    soup = BeautifulSoup(content, "lxml")
    # List of all matches
    matches = soup.find_all("div", class_="footballbox") # where div is the tag

    home = []
    score = []
    away = []

    for match in matches:
        home.append(match.find("th", class_="fhome").get_text())
        score.append(match.find("th", class_="fscore").get_text())
        away.append(match.find("th", class_="faway").get_text())
    
    # Create a dictionary
    fifa_dict = {"home":home, "score":score, "away":away}

    #Create a df
    fifa_df = pd.DataFrame(fifa_dict)
    fifa_df["year"] = year
    return fifa_df
get_matches(2018)
# Out:
#         home         score           away  year
# 0    Russia            5–0   Saudi Arabia  2018
# 1     Egypt            0–1        Uruguay  2018
# 2    Russia            3–1          Egypt  2018
# 3   Uruguay            1–0   Saudi Arabia  2018
# 4   Uruguay            3–0         Russia  2018
# ..       ...           ...            ...   ...
# 59   Russia   2–2 (a.e.t.)        Croatia  2018
# 60   France            1–0        Belgium  2018
# 61  Croatia   2–1 (a.e.t.)        England  2018
# 62  Belgium            2–0        England  2018
# 63   France            4–2        Croatia  2018
#
# [64 rows x 4 columns]

# %% [markdown]
# * For some years, we can't extract all data because of difference in html

# %%
all_fifa = [get_matches(year) for year in years]
fifa = pd.concat(all_fifa, ignore_index = True)
fifa.to_csv("fifa_world_cup_historical_data.csv",index = False)

# %% [markdown]
# ### 2022 World Cup Fixtures

# %%
fixture_df = get_matches(2022)
fixture_df.to_csv("fifa_2022_world_cup_fixtures.csv", index = False)
